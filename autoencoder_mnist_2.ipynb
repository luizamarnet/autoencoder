# %%
import tarfile
import matplotlib.pyplot as plt
import matplotlib  #ajustar
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import backend as K
import idx2numpy
import csv

import import_ipynb
from utils import *
from autoencoder_and_clustering_models import *
# Out:
# importing Jupyter notebook from utils.ipynb
# importing Jupyter notebook from autoencoder_and_clustering_models.ipynb

# %%
def read_preprocess_dataset( indexes_train, indexes_val = np.empty(0)):

    file = 'D:\\Luiza\\OneDrive\\Documentos\\Doutorado\\MeusProjetos\\cifar_10_kmeans\\train-images-idx3-ubyte\\train-images.idx3-ubyte'
    img_train_val = idx2numpy.convert_from_file(file)

    file = 'D:\\Luiza\\OneDrive\\Documentos\\Doutorado\\MeusProjetos\\cifar_10_kmeans\\t10k-images-idx3-ubyte\\t10k-images.idx3-ubyte'
    img_test = idx2numpy.convert_from_file(file)

    file = 'D:\\Luiza\\OneDrive\\Documentos\\Doutorado\\MeusProjetos\\cifar_10_kmeans\\train-labels-idx1-ubyte\\train-labels.idx1-ubyte'
    target_train_val = idx2numpy.convert_from_file(file)

    file = 'D:\\Luiza\\OneDrive\\Documentos\\Doutorado\\MeusProjetos\\cifar_10_kmeans\\t10k-labels-idx1-ubyte\\t10k-labels.idx1-ubyte'
    target_test = idx2numpy.convert_from_file(file)
    
    
    indexes_train = indexes_train.astype(int)
    indexes_val = indexes_val.astype(int)
    
    data_train_val = np.expand_dims(img_train_val, axis=3)
    data_test = np.expand_dims(img_test, axis=3)

    data_train_val = data_train_val/255
    data_test = data_test/255
    
    
    if indexes_val.size==0:
        data_train = data_train_val
        target_train = target_train_val
        
        return data_train, data_test, target_train, target_test
    
    else:
        data_train = data_train_val[indexes_train]
        target_train = target_train_val[indexes_train]
        
        data_val = data_train_val[indexes_val]
        target_val = target_train_val[indexes_val]
        
        return data_train, data_val, data_test, target_train, target_val, target_test

# %%
model = model_encoder(input_shape=(28,28,1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_0 (Conv2D)              (None, 28, 28, 32)        1600
# _________________________________________________________________
# AC_0 (Activation)            (None, 28, 28, 32)        0
# _________________________________________________________________
# BN_0 (BatchNormalization)    (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pool_0 (MaxPooling2D)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 14, 14, 16)        12816
# _________________________________________________________________
# AC_1 (Activation)            (None, 14, 14, 16)        0
# _________________________________________________________________
# BN_1 (BatchNormalization)    (None, 14, 14, 16)        64
# _________________________________________________________________
# max_pool_1 (MaxPooling2D)    (None, 7, 7, 16)          0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 7, 7, 8)           1160
# _________________________________________________________________
# AC_2 (Activation)            (None, 7, 7, 8)           0
# _________________________________________________________________
# BN_2 (BatchNormalization)    (None, 7, 7, 8)           32
# _________________________________________________________________
# flatten (Flatten)            (None, 392)               0
# _________________________________________________________________
# AC_3 (Activation)            (None, 392)               0
# _________________________________________________________________
# BN_3 (BatchNormalization)    (None, 392)               1568
# _________________________________________________________________
# dense (Dense)                (None, 128)               50304
# _________________________________________________________________
# encoderLayer_AC (Activation) (None, 128)               0
# _________________________________________________________________
# encoderLayer_BN (BatchNormal (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 392)               50568
# _________________________________________________________________
# AC_4 (Activation)            (None, 392)               0
# _________________________________________________________________
# BN_4 (BatchNormalization)    (None, 392)               1568
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 8)           0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 7, 7, 8)           584
# _________________________________________________________________
# AC_5 (Activation)            (None, 7, 7, 8)           0
# _________________________________________________________________
# BN_5 (BatchNormalization)    (None, 7, 7, 8)           32
# _________________________________________________________________
# US_0 (UpSampling2D)          (None, 14, 14, 8)         0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 14, 14, 16)        3216
# _________________________________________________________________
# AC_6 (Activation)            (None, 14, 14, 16)        0
# _________________________________________________________________
# BN_6 (BatchNormalization)    (None, 14, 14, 16)        64
# _________________________________________________________________
# UP_1 (UpSampling2D)          (None, 28, 28, 16)        0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 28, 28, 32)        25120
# _________________________________________________________________
# AC_7 (Activation)            (None, 28, 28, 32)        0
# _________________________________________________________________
# last_conv (Conv2D)           (None, 28, 28, 1)         289
# _________________________________________________________________
# finalLayer_AC (Activation)   (None, 28, 28, 1)         0
# =================================================================
# Total params: 149,625
# Trainable params: 147,641
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
def train_evaluate(n_epoch, b_size, arq_path, list_indexes):

    
    train_mse = np.zeros((5))
    val_mse = np.zeros((5))
    
    for i_crossVal in range(5):

        
        
        i_train = np.array([w for w in range(5) if not w == i_crossVal])
        
        indexes_val = list_indexes[i_crossVal]
        indexes_train = np.empty(0)
        for i in range(len(i_train)):
            indexes_train = np.concatenate ((indexes_train, list_indexes[i_train[i]]), axis=0 )
        indexes_val = np.array(indexes_val)
        indexes_train = np.array(indexes_train)
        
        data_train, data_val, data_test, label_train, label_val, label_test = read_preprocess_dataset( indexes_train, indexes_val ) 


        input_shape = (data_train.shape[1],data_train.shape[2],data_train.shape[3])
        model = model_encoder(input_shape=input_shape, n_classes=10)
        
        # Train


        arq_model=arq_path + '\\Encoder_model_'+str(i_crossVal)+'.h5'
        checkpoint =  tf.keras.callbacks.ModelCheckpoint(
        arq_model, 
        monitor='val_loss', 
        mode='min',
        verbose=0, 
        save_best_only=True, 
        save_weights_only=False,
      
        )
        opt = tf.keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
       # opt = tf.keras.optimizers.Adagrad(learning_rate=0.001, initial_accumulator_value=0.1, epsilon=1e-07 )
        model.compile(loss = 'mse', optimizer=opt)
    #    model.compile(loss='mse', optimizer=opt)
        history = model.fit(x=data_train, y=data_train, validation_data=(data_val, data_val), batch_size=b_size, epochs=n_epoch, callbacks=[checkpoint])
    #    model.save(arq_path + '\Encoder_model_'+str(i_crossVal)+'.h5')

        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('Mean Squared Error')
        plt.xlabel('Epoch')
  #      plt.yscale('log')
        plt.legend(['train', 'validation'], loc='upper left')
        plt.savefig(arq_path + '\Encoder_TrainHistory_loss_'+str(i_crossVal)+'.jpg')
        plt.show()
        
       
        model = tf.keras.models.load_model(arq_path + '\Encoder_model_'+str(i_crossVal)+'.h5')
        train_mse[i_crossVal] = model.evaluate(x=data_train, y=data_train, batch_size=b_size)
        val_mse[i_crossVal] = model.evaluate(x=data_val, y=data_val, batch_size=b_size)
        
  #      train_loss[i_crossVal] = model.evaluate(x=data_train, y=data_train, batch_size=b_size)
  #      val_loss[i_crossVal] = model.evaluate(x=data_val, y=data_val, batch_size=b_size)
        
    train_mse_mean = np.mean(train_mse)
    val_mse_mean = np.mean(val_mse)
    
    train_mse_std = np.std(train_mse)
    val_mse_std = np.std(val_mse)
    
       
    
    print('The Mean Train MSE for the Cross-Validation = ', train_mse_mean, ' - with Standard Deviation = ', train_mse_std)
    print('The Mean Validation MSE for the Cross-Validation = ', val_mse_mean, ' - with Standard Deviation = ', val_mse_std)

# %%
arq_path = 'D:\Luiza\OneDrive\Documentos\Doutorado\MeusProjetos\\autoencoder\\mnist_rev2'

file = 'D:\\Luiza\\OneDrive\\Documentos\\Doutorado\\MeusProjetos\\cifar_10_kmeans\\train-images-idx3-ubyte\\train-images.idx3-ubyte'
img_train_val = idx2numpy.convert_from_file(file)
    
k_folds = 5
indexes = np.arange(len(img_train_val))
np.random.shuffle(indexes)
end_sublist = 0
list_indexes = []
for i in range (k_folds):
    begin_sublist = end_sublist
    end_sublist = int( (i+1) * len(img_train_val)/k_folds) 
    list_indexes.append(list( indexes[begin_sublist:end_sublist] ))
                
with open(arq_path+"_crossValidation_indexes.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(list_indexes)
    
del img_train_val


train_evaluate(n_epoch=70, b_size=32, arq_path = arq_path, list_indexes=list_indexes)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/70
# 48000/48000 [==============================] - 123s 3ms/sample - loss: 0.0625 - val_loss: 0.0452
# Epoch 2/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0437 - val_loss: 0.0373
# Epoch 3/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0392 - val_loss: 0.0337
# Epoch 4/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0367 - val_loss: 0.0312
# Epoch 5/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0348 - val_loss: 0.0295
# Epoch 6/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0332 - val_loss: 0.0276
# Epoch 7/70
# 48000/48000 [==============================] - 110s 2ms/sample - loss: 0.0318 - val_loss: 0.0261
# Epoch 8/70
# 48000/48000 [==============================] - 78s 2ms/sample - loss: 0.0305 - val_loss: 0.0248
# Epoch 9/70
# 48000/48000 [==============================] - 78s 2ms/sample - loss: 0.0292 - val_loss: 0.0235
# Epoch 10/70
# 48000/48000 [==============================] - 88s 2ms/sample - loss: 0.0283 - val_loss: 0.0225
# Epoch 11/70
# 48000/48000 [==============================] - 89s 2ms/sample - loss: 0.0274 - val_loss: 0.0218
# Epoch 12/70
# 48000/48000 [==============================] - 119s 2ms/sample - loss: 0.0266 - val_loss: 0.0210
# Epoch 13/70
# 48000/48000 [==============================] - 122s 3ms/sample - loss: 0.0258 - val_loss: 0.0202
# Epoch 14/70
# 48000/48000 [==============================] - 119s 2ms/sample - loss: 0.0251 - val_loss: 0.0196
# Epoch 15/70
# 48000/48000 [==============================] - 130s 3ms/sample - loss: 0.0245 - val_loss: 0.0190
# Epoch 16/70
# 48000/48000 [==============================] - 141s 3ms/sample - loss: 0.0241 - val_loss: 0.0186
# Epoch 17/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0235 - val_loss: 0.0182
# Epoch 18/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0232 - val_loss: 0.0178
# Epoch 19/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0228 - val_loss: 0.0173
# Epoch 20/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0224 - val_loss: 0.0172
# Epoch 21/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0220 - val_loss: 0.0168
# Epoch 22/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0218 - val_loss: 0.0167
# Epoch 23/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0215 - val_loss: 0.0164
# Epoch 24/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0213 - val_loss: 0.0160
# Epoch 25/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0211 - val_loss: 0.0159
# Epoch 26/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0208 - val_loss: 0.0158
# Epoch 27/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0207 - val_loss: 0.0156
# Epoch 28/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0205 - val_loss: 0.0154
# Epoch 29/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0203 - val_loss: 0.0155
# Epoch 30/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0202 - val_loss: 0.0153
# Epoch 31/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0201 - val_loss: 0.0154
# Epoch 32/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0199 - val_loss: 0.0150
# Epoch 33/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0199 - val_loss: 0.0151
# Epoch 34/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0196 - val_loss: 0.0149
# Epoch 35/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0196 - val_loss: 0.0147
# Epoch 36/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0194 - val_loss: 0.0146
# Epoch 37/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0194 - val_loss: 0.0145
# Epoch 38/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0192 - val_loss: 0.0145
# Epoch 39/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0192 - val_loss: 0.0145
# Epoch 40/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0191 - val_loss: 0.0144
# Epoch 41/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0189 - val_loss: 0.0142
# Epoch 42/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0188 - val_loss: 0.0143
# Epoch 43/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0141
# Epoch 44/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0187 - val_loss: 0.0143
# Epoch 45/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0141
# Epoch 46/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0141
# Epoch 47/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0184 - val_loss: 0.0139
# Epoch 48/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0184 - val_loss: 0.0139
# Epoch 49/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0139
# Epoch 50/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0139
# Epoch 51/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0136
# Epoch 52/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0182 - val_loss: 0.0136
# Epoch 53/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0137
# Epoch 54/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0180 - val_loss: 0.0136
# Epoch 55/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0135
# Epoch 56/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0135
# Epoch 57/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0134
# Epoch 58/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0177 - val_loss: 0.0135
# Epoch 59/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0177 - val_loss: 0.0134
# Epoch 60/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0134
# Epoch 61/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0132
# Epoch 62/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0133
# Epoch 63/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0133
# Epoch 64/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0132
# Epoch 65/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# Epoch 66/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0131
# Epoch 67/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# Epoch 68/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# Epoch 69/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0172 - val_loss: 0.0132
# Epoch 70/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0171 - val_loss: 0.0133
# 48000/48000 [==============================] - 41s 860us/sample - loss: 0.0127
# 12000/12000 [==============================] - 10s 855us/sample - loss: 0.0131
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0614 - val_loss: 0.0453
# Epoch 2/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0443 - val_loss: 0.0380
# Epoch 3/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0398 - val_loss: 0.0341
# Epoch 4/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0372 - val_loss: 0.0314
# Epoch 5/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0353 - val_loss: 0.0294
# Epoch 6/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0336 - val_loss: 0.0279
# Epoch 7/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0322 - val_loss: 0.0266
# Epoch 8/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0311 - val_loss: 0.0252
# Epoch 9/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0299 - val_loss: 0.0242
# Epoch 10/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0289 - val_loss: 0.0235
# Epoch 11/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0280 - val_loss: 0.0223
# Epoch 12/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0273 - val_loss: 0.0216
# Epoch 13/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0265 - val_loss: 0.0208
# Epoch 14/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0258 - val_loss: 0.0203
# Epoch 15/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0252 - val_loss: 0.0197
# Epoch 16/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0247 - val_loss: 0.0190
# Epoch 17/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0241 - val_loss: 0.0185
# Epoch 18/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0236 - val_loss: 0.0181
# Epoch 19/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0232 - val_loss: 0.0176
# Epoch 20/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0227 - val_loss: 0.0173
# Epoch 21/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0224 - val_loss: 0.0171
# Epoch 22/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0221 - val_loss: 0.0167
# Epoch 23/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0218 - val_loss: 0.0166
# Epoch 24/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0216 - val_loss: 0.0164
# Epoch 25/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0213 - val_loss: 0.0161
# Epoch 26/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0212 - val_loss: 0.0161
# Epoch 27/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0210 - val_loss: 0.0159
# Epoch 28/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0208 - val_loss: 0.0157
# Epoch 29/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0205 - val_loss: 0.0154
# Epoch 30/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0204 - val_loss: 0.0152
# Epoch 31/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0203 - val_loss: 0.0152
# Epoch 32/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0201 - val_loss: 0.0151
# Epoch 33/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0200 - val_loss: 0.0151
# Epoch 34/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0199 - val_loss: 0.0149
# Epoch 35/70
# 48000/48000 [==============================] - 153s 3ms/sample - loss: 0.0198 - val_loss: 0.0148
# Epoch 36/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0197 - val_loss: 0.0147
# Epoch 37/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0196 - val_loss: 0.0146
# Epoch 38/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0194 - val_loss: 0.0144
# Epoch 39/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0193 - val_loss: 0.0144
# Epoch 40/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0192 - val_loss: 0.0144
# Epoch 41/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0191 - val_loss: 0.0143
# Epoch 42/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0190 - val_loss: 0.0141
# Epoch 43/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0142
# Epoch 44/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0141
# Epoch 45/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0187 - val_loss: 0.0140
# Epoch 46/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0139
# Epoch 47/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0185 - val_loss: 0.0139
# Epoch 48/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0138
# Epoch 49/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0184 - val_loss: 0.0138
# Epoch 50/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0136
# Epoch 51/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0137
# Epoch 52/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0182 - val_loss: 0.0136
# Epoch 53/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0136
# Epoch 54/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0135
# Epoch 55/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0135
# Epoch 56/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0134
# Epoch 57/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0134
# Epoch 58/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0133
# Epoch 59/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0177 - val_loss: 0.0133
# Epoch 60/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0177 - val_loss: 0.0133
# Epoch 61/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0133
# Epoch 62/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0133
# Epoch 63/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0132
# Epoch 64/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0132
# Epoch 65/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0133
# Epoch 66/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0133
# Epoch 67/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0131
# Epoch 68/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0131
# Epoch 69/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0130
# Epoch 70/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0172 - val_loss: 0.0131
# 48000/48000 [==============================] - 41s 861us/sample - loss: 0.0127
# 12000/12000 [==============================] - 10s 858us/sample - loss: 0.0130
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0661 - val_loss: 0.0497
# Epoch 2/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0463 - val_loss: 0.0402
# Epoch 3/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0410 - val_loss: 0.0358
# Epoch 4/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0378 - val_loss: 0.0327
# Epoch 5/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0354 - val_loss: 0.0302
# Epoch 6/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0336 - val_loss: 0.0285
# Epoch 7/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0320 - val_loss: 0.0268
# Epoch 8/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0307 - val_loss: 0.0255
# Epoch 9/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0296 - val_loss: 0.0245
# Epoch 10/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0286 - val_loss: 0.0234
# Epoch 11/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0277 - val_loss: 0.0225
# Epoch 12/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0270 - val_loss: 0.0220
# Epoch 13/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0263 - val_loss: 0.0212
# Epoch 14/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0257 - val_loss: 0.0206
# Epoch 15/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0251 - val_loss: 0.0201
# Epoch 16/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0247 - val_loss: 0.0198
# Epoch 17/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0242 - val_loss: 0.0196
# Epoch 18/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0238 - val_loss: 0.0189
# Epoch 19/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0235 - val_loss: 0.0186
# Epoch 20/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0231 - val_loss: 0.0183
# Epoch 21/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0227 - val_loss: 0.0178
# Epoch 22/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0224 - val_loss: 0.0175
# Epoch 23/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0221 - val_loss: 0.0176
# Epoch 24/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0218 - val_loss: 0.0169
# Epoch 25/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0215 - val_loss: 0.0173
# Epoch 26/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0213 - val_loss: 0.0166
# Epoch 27/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0211 - val_loss: 0.0164
# Epoch 28/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0209 - val_loss: 0.0162
# Epoch 29/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0207 - val_loss: 0.0160
# Epoch 30/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0206 - val_loss: 0.0159
# Epoch 31/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0204 - val_loss: 0.0160
# Epoch 32/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0203 - val_loss: 0.0156
# Epoch 33/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0201 - val_loss: 0.0156
# Epoch 34/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0200 - val_loss: 0.0157
# Epoch 35/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0198 - val_loss: 0.0152
# Epoch 36/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0197 - val_loss: 0.0151
# Epoch 37/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0195 - val_loss: 0.0150
# Epoch 38/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0195 - val_loss: 0.0149
# Epoch 39/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0194 - val_loss: 0.0151
# Epoch 40/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0192 - val_loss: 0.0148
# Epoch 41/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0191 - val_loss: 0.0146
# Epoch 42/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0190 - val_loss: 0.0148
# Epoch 43/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0189 - val_loss: 0.0145
# Epoch 44/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0189 - val_loss: 0.0145
# Epoch 45/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0145
# Epoch 46/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0143
# Epoch 47/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0144
# Epoch 48/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0143
# Epoch 49/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0143
# Epoch 50/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0141
# Epoch 51/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0142
# Epoch 52/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0182 - val_loss: 0.0139
# Epoch 53/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0182 - val_loss: 0.0141
# Epoch 54/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0139
# Epoch 55/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0139
# Epoch 56/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0138
# Epoch 57/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0138
# Epoch 58/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0138
# Epoch 59/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0139
# Epoch 60/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0177 - val_loss: 0.0136
# Epoch 61/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0135
# Epoch 62/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0137
# Epoch 63/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0136
# Epoch 64/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0135
# Epoch 65/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0137
# Epoch 66/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0174 - val_loss: 0.0134
# Epoch 67/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0134
# Epoch 68/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0135
# Epoch 69/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0134
# Epoch 70/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# 48000/48000 [==============================] - 41s 860us/sample - loss: 0.0128
# 12000/12000 [==============================] - 10s 856us/sample - loss: 0.0133
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0727 - val_loss: 0.0544
# Epoch 2/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0488 - val_loss: 0.0426
# Epoch 3/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0424 - val_loss: 0.0374
# Epoch 4/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0390 - val_loss: 0.0337
# Epoch 5/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0366 - val_loss: 0.0314
# Epoch 6/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0344 - val_loss: 0.0292
# Epoch 7/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0329 - val_loss: 0.0278
# Epoch 8/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0316 - val_loss: 0.0264
# Epoch 9/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0304 - val_loss: 0.0253
# Epoch 10/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0294 - val_loss: 0.0242
# Epoch 11/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0284 - val_loss: 0.0232
# Epoch 12/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0275 - val_loss: 0.0222
# Epoch 13/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0266 - val_loss: 0.0215
# Epoch 14/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0259 - val_loss: 0.0207
# Epoch 15/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0252 - val_loss: 0.0202
# Epoch 16/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0246 - val_loss: 0.0195
# Epoch 17/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0239 - val_loss: 0.0191
# Epoch 18/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0234 - val_loss: 0.0185
# Epoch 19/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0230 - val_loss: 0.0181
# Epoch 20/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0225 - val_loss: 0.0176
# Epoch 21/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0221 - val_loss: 0.0174
# Epoch 22/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0216 - val_loss: 0.0171
# Epoch 23/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0213 - val_loss: 0.0165
# Epoch 24/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0211 - val_loss: 0.0163
# Epoch 25/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0209 - val_loss: 0.0160
# Epoch 26/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0206 - val_loss: 0.0159
# Epoch 27/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0204 - val_loss: 0.0157
# Epoch 28/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0202 - val_loss: 0.0156
# Epoch 29/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0200 - val_loss: 0.0154
# Epoch 30/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0198 - val_loss: 0.0152
# Epoch 31/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0197 - val_loss: 0.0152
# Epoch 32/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0195 - val_loss: 0.0149
# Epoch 33/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0193 - val_loss: 0.0150
# Epoch 34/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0192 - val_loss: 0.0148
# Epoch 35/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0191 - val_loss: 0.0147
# Epoch 36/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0190 - val_loss: 0.0146
# Epoch 37/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0144
# Epoch 38/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0145
# Epoch 39/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0143
# Epoch 40/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0141
# Epoch 41/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0141
# Epoch 42/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0141
# Epoch 43/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0139
# Epoch 44/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0139
# Epoch 45/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0139
# Epoch 46/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0138
# Epoch 47/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0179 - val_loss: 0.0137
# Epoch 48/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0137
# Epoch 49/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0138
# Epoch 50/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0135
# Epoch 51/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0136
# Epoch 52/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0135
# Epoch 53/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0136
# Epoch 54/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0135
# Epoch 55/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0134
# Epoch 56/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# Epoch 57/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0133
# Epoch 58/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0172 - val_loss: 0.0133
# Epoch 59/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0171 - val_loss: 0.0132
# Epoch 60/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0170 - val_loss: 0.0132
# Epoch 61/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0170 - val_loss: 0.0131
# Epoch 62/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0169 - val_loss: 0.0131
# Epoch 63/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0169 - val_loss: 0.0130
# Epoch 64/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0168 - val_loss: 0.0130
# Epoch 65/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0168 - val_loss: 0.0133
# Epoch 66/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0167 - val_loss: 0.0131
# Epoch 67/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0167 - val_loss: 0.0129
# Epoch 68/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0167 - val_loss: 0.0129
# Epoch 69/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0166 - val_loss: 0.0129
# Epoch 70/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0165 - val_loss: 0.0129
# 48000/48000 [==============================] - 41s 862us/sample - loss: 0.0123
# 12000/12000 [==============================] - 10s 857us/sample - loss: 0.0129
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0671 - val_loss: 0.0487
# Epoch 2/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0464 - val_loss: 0.0401
# Epoch 3/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0414 - val_loss: 0.0360
# Epoch 4/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0383 - val_loss: 0.0331
# Epoch 5/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0361 - val_loss: 0.0305
# Epoch 6/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0342 - val_loss: 0.0285
# Epoch 7/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0327 - val_loss: 0.0271
# Epoch 8/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0313 - val_loss: 0.0266
# Epoch 9/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0302 - val_loss: 0.0247
# Epoch 10/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0291 - val_loss: 0.0234
# Epoch 11/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0282 - val_loss: 0.0226
# Epoch 12/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0273 - val_loss: 0.0216
# Epoch 13/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0265 - val_loss: 0.0211
# Epoch 14/70
# 48000/48000 [==============================] - 144s 3ms/sample - loss: 0.0258 - val_loss: 0.0203
# Epoch 15/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0252 - val_loss: 0.0199
# Epoch 16/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0248 - val_loss: 0.0194
# Epoch 17/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0244 - val_loss: 0.0189
# Epoch 18/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0239 - val_loss: 0.0185
# Epoch 19/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0236 - val_loss: 0.0183
# Epoch 20/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0231 - val_loss: 0.0180
# Epoch 21/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0228 - val_loss: 0.0177
# Epoch 22/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0225 - val_loss: 0.0176
# Epoch 23/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0222 - val_loss: 0.0170
# Epoch 24/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0219 - val_loss: 0.0168
# Epoch 25/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0217 - val_loss: 0.0167
# Epoch 26/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0214 - val_loss: 0.0163- - E
# Epoch 27/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0212 - val_loss: 0.0163
# Epoch 28/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0210 - val_loss: 0.0160
# Epoch 29/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0208 - val_loss: 0.0157
# Epoch 30/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0207 - val_loss: 0.0159
# Epoch 31/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0205 - val_loss: 0.0155
# Epoch 32/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0203 - val_loss: 0.0153
# Epoch 33/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0201 - val_loss: 0.0153
# Epoch 34/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0200 - val_loss: 0.0154
# Epoch 35/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0199 - val_loss: 0.0150
# Epoch 36/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0197 - val_loss: 0.0150
# Epoch 37/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0196 - val_loss: 0.0149
# Epoch 38/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0195 - val_loss: 0.0148
# Epoch 39/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0194 - val_loss: 0.0147
# Epoch 40/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0193 - val_loss: 0.0153
# Epoch 41/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0191 - val_loss: 0.0146
# Epoch 42/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0191 - val_loss: 0.0146
# Epoch 43/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0190 - val_loss: 0.0144
# Epoch 44/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0189 - val_loss: 0.0144
# Epoch 45/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0188 - val_loss: 0.0145
# Epoch 46/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0187 - val_loss: 0.0142
# Epoch 47/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0187 - val_loss: 0.0141
# Epoch 48/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0186 - val_loss: 0.0141
# Epoch 49/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0185 - val_loss: 0.0142
# Epoch 50/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0139
# Epoch 51/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0183 - val_loss: 0.0141
# Epoch 52/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0182 - val_loss: 0.0140
# Epoch 53/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0137
# Epoch 54/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0181 - val_loss: 0.0138
# Epoch 55/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0137
# Epoch 56/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0180 - val_loss: 0.0138
# Epoch 57/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0179 - val_loss: 0.0138
# Epoch 58/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0136
# Epoch 59/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0178 - val_loss: 0.0136
# Epoch 60/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0177 - val_loss: 0.0137
# Epoch 61/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0135
# Epoch 62/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0134
# Epoch 63/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0176 - val_loss: 0.0133
# Epoch 64/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0175 - val_loss: 0.0133
# Epoch 65/70
# 48000/48000 [==============================] - 143s 3ms/sample - loss: 0.0174 - val_loss: 0.0136
# Epoch 66/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0132
# Epoch 67/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0174 - val_loss: 0.0132
# Epoch 68/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0172 - val_loss: 0.0133
# Epoch 69/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0132
# Epoch 70/70
# 48000/48000 [==============================] - 142s 3ms/sample - loss: 0.0173 - val_loss: 0.0131
# 48000/48000 [==============================] - 41s 856us/sample - loss: 0.0127
# 12000/12000 [==============================] - 10s 854us/sample - loss: 0.0131
# The Mean Train MSE for the Cross-Validation =  0.01263967816097041  - with Standard Deviation =  0.0001958545449171661
# The Mean Validation MSE for the Cross-Validation =  0.013083840098480381  - with Standard Deviation =  0.0001528054692317229

# %%
arq_path = 'D:\Luiza\OneDrive\Documentos\Doutorado\MeusProjetos\\autoencoder\mnist_rev2'

with open(arq_path+"\crossValidation_indexes.csv", newline='') as f:
    list_indexes = csv.reader(f)
    list_indexes = list(list(rec) for rec in csv.reader(f, delimiter=','))
(np.array(list_indexes)).astype(int)


i_crossVal = 0
i_train = np.array([w for w in range(5) if not w == i_crossVal])
indexes_val = list_indexes[i_crossVal]
indexes_train = np.empty(0)
for i in range(len(i_train)):
    indexes_train = np.concatenate ((indexes_train, list_indexes[i_train[i]]), axis=0 )
indexes_val = np.array(indexes_val)
indexes_train = np.array(indexes_train)
        
data_train, data_val, data_test, label_train, label_val, label_test = read_preprocess_dataset( indexes_train, indexes_val ) 



i = np.random.choice(range(len(data_test)),25)

t=0
plt.figure()
fig, axes1 = plt.subplots(5,5,figsize=(3,3))
i_aux=np.zeros((5,5))
for j in range(5):
    for k in range(5):
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(np.squeeze(data_test[i[t]]), cmap=plt.cm.binary)
        t+=1
fig.suptitle('25 Original Images from the Test Dataset')
plt.show()  
    
test_mse = np.zeros((5))

for i_crossVal in range(5):
    
   
    model = tf.keras.models.load_model(arq_path + '\Encoder_model_'+str(i_crossVal)+'.h5')
    
        
    y_hat=model.predict( data_test[i] )

    t=0
    plt.figure()
    fig, axes1 = plt.subplots(5,5,figsize=(3,3))
    for j in range(5):
        for k in range(5):
            axes1[j][k].set_axis_off()
            axes1[j][k].imshow(np.squeeze(y_hat[t]), cmap=plt.cm.binary)
            t+=1
    fig.suptitle('Imagens Reconstructed by the Autoencoder Validated with Dataset from Fold ' + str(i_crossVal))
    plt.show()
    test_mse[i_crossVal] = model.evaluate(x=data_test, y=data_test, batch_size=128)
            
test_mse_mean = np.mean(test_mse)
test_mse_std = np.std(test_mse)


print('The Mean Test MSE for the Cross-Validation = ', test_mse_mean, ' - with Standard Deviation = ', test_mse_std)
# Out:
# 10000/10000 [==============================] - 3s 306us/sample - loss: 0.0130
# 10000/10000 [==============================] - 2s 247us/sample - loss: 0.0129
# 10000/10000 [==============================] - 2s 246us/sample - loss: 0.0131
# 10000/10000 [==============================] - 3s 251us/sample - loss: 0.0126
# 10000/10000 [==============================] - 2s 246us/sample - loss: 0.0131
# The Mean Test MSE for the Cross-Validation =  0.012924143428206445  - with Standard Deviation =  0.00019099511110892757
